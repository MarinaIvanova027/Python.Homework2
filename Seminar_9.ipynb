# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaIvanova027/Python.Homework2/blob/main/Seminar_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Семинар 9
#
# ## Задача №57.
# 1. Прочесть с помощью pandas файл
# california_housing_test.csv, который находится в папке
# sample_data
# 2. Посмотреть сколько в нем строк и столбцов
# 3. Определить какой тип данных имеют столбцы

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# ## Задача №59.
# 1. Проверить есть ли в файле пустые значения
# 2. Показать median_house_value где median_income < 2
# 3. Показать данные в первых 2 столбцах
# 4. Выбрать данные где housing_median_age < 20 и
# median_house_value > 70000

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df[df['median_income'] < 2]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5       -119.56     36.51                37.0       1018.0           213.0
# 6       -121.43     38.63                43.0       1009.0           225.0
# 16      -120.81     37.53                15.0        570.0           123.0
# 28      -118.45     34.07                19.0       4845.0          1609.0
# 43      -117.27     34.09                36.0        848.0           186.0
# ...         ...       ...                 ...          ...             ...
# 2943    -121.23     37.96                37.0       2351.0           564.0
# 2964    -118.25     33.94                43.0       1113.0           378.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2986    -118.25     33.93                42.0        819.0           233.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[df['median_income'] < 2][['median_house_value']]
# Out:
#       median_house_value
# 5                67000.0
# 6                67000.0
# 16              181300.0
# 28              350000.0
# 43               79300.0
# ...                  ...
# 2943             57200.0
# 2964             91300.0
# 2985            109400.0
# 2986             85400.0
# 2995            225000.0
#
# [360 rows x 1 columns]

# %%
df.iloc[:, :2]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.loc[:, :'latitude']
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df[
    (df['housing_median_age'] < 20) &
    (df['median_house_value'] > 70000)
]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# ## Задача №61.
# 1. Определить какое максимальное и минимальное
# значение median_house_value
# 2. Показать максимальное median_house_value, где
# median_income = 3.1250
# 3. Узнать какая максимальная population в зоне
# минимального значения median_house_value

# %%
df['median_house_value'].min()
# Out:
# 22500.0

# %%
df['median_house_value'].max()
# Out:
# 500001.0

# %%
df[df['median_income'] == 3.1250]['median_house_value'].max()
# Out:
# 233300.0

# %%
df[df['median_house_value'] == df['median_house_value'].min()].population.max()
# Out:
# 1230.0

# %% [markdown]
# # Домашнее задание

# %% [markdown]
# ## Задача 40:
# 1. Работать с файлом california_housing_train.csv, который находится в папке
# sample_data.
# 2. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
# я точно не поняла как программа расчитает. <500 эо будет включительно или нет??
# на семинаре такое не обсуждалось и просто писали числа из задачи...

df[df['population'] < 500]['median_house_value'].mean()
# Out:
# 206683.83635227982

# %%
# но если вдруг 500 не включительно, то вот так:

df[df['population'] < 501]['median_house_value'].mean()
# Out:
# 206799.95140186916

# %% [markdown]
# ## Задача 42.
# Узнать какая максимальная households в зоне минимального значения population.

# %%
df[df['population'] == df['population'].min()].households.max()
# Out:
# 4.0
